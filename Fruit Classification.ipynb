# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r'fruit_data_with_colors.txt', sep='\t')
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
labels = dict(zip(df.fruit_label.unique(), df.fruit_name.unique()))   
labels
# Out:
# {1: 'apple', 2: 'mandarin', 3: 'orange', 4: 'lemon'}

# %%
plt.scatter(df['width'], df['height'])

# %%
plt.scatter(df['mass'], df['color_score'])

# %%
plt.plot(df['height'], label='height')
plt.plot(df['width'], label='width')
plt.legend()

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

X = df[['mass', 'width', 'height']]
y = df['fruit_label']
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
X_train.describe()
# Out:
#              mass      width     height
# count   44.000000  44.000000  44.000000
# mean   171.272727   7.234091   7.770455
# std     59.081482   0.838588   1.332698
# min     76.000000   5.800000   4.000000
# 25%    149.500000   7.075000   7.200000
# 50%    163.000000   7.300000   7.600000
# 75%    181.500000   7.500000   8.275000
# max    362.000000   9.600000  10.300000

# %%
X_test.describe()
# Out:
#              mass      width     height
# count   15.000000  15.000000  15.000000
# mean   139.200000   6.726667   7.466667
# std     31.584806   0.631853   1.464663
# min     80.000000   5.900000   4.300000
# 25%    118.000000   6.100000   7.250000
# 50%    150.000000   6.800000   7.500000
# 75%    155.000000   7.250000   8.050000
# max    200.000000   7.700000  10.500000

# %%
model = KNeighborsClassifier()
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
model.score(X_test, y_test)
# Out:
# 0.6666666666666666
